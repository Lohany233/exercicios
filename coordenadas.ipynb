# %%
import folium
# Definindo as coordenadas de porto Alegre
latitude = -30.0346
longitude = -51.2177

# Criando um mapa centrado em Porto Alegre
mapa = folium.Map(localition=[latitude, longitude], zoom_start=12)

# Adicionando um marcador para Porto Alegre
folium.Marker([latitude, longitude], popup='Porto Alegre, RS, Brasil').add_to(mapa)


# Exibindo o mapa
mapa
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
# ...

# %% [markdown]
# # Coordenadas das cidades

# %%
import folium

# %% [markdown]
# coordenadas =
# 'Porto Alegre': [-30.0346, -51.2177],
# 'São Paulo': [-23.5505], -46.6333],
# 'Rio de Janeiro': [-22.9068, -43.1729],
# 'Curitiba': [-25.4290, -49.2671],
# 'Belo Horizonte': [-19.9173, -43.9345],

# %%
import folium
# Definindo as coordenadas de porto Alegre
latitude = -30.0346
longitude = -51.2177

# Definindo as coordenadas de São Paulo
latitude2 = -23.5505
longitude2 = -51.2177 

# Definindo as coordenadas de Rio de Janeiro
latitude3 = -22.9068
longitude3 = -43.1729

# Definindo as coordenadas de Curitiba
latitude4 = -25.4290
longitude4 = -49.2671

# Definindo as coordenadas de Belo Horizonte
latitude5 = -19.9173
longitude5= -43.9345

# Criando um mapa centrado em Porto Alegre
mapa = folium.Map(localition=[latitude, longitude], zoom_start=12)

# Adicionando marcadores para Porto Alegre
folium.Marker([latitude, longitude], popup= 'Porto Alegre, RS, Brasil').add_to(mapa)
folium.Marker([latitude2, longitude2], popup= 'Porto Alegre, RS, Brasil').add_to(mapa)
folium.Marker([latitude3, longitude3], popup= 'Porto Alegre, RS, Brasil').add_to(mapa)
folium.Marker([latitude4, longitude4], popup= 'Porto Alegre, RS, Brasil').add_to(mapa)
folium.Marker([latitude5, longitude5], popup= 'Porto Alegre, RS, Brasil').add_to(mapa)

# %%
# Exibindo o mapa
mapa
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
# ...

# %%
# Definindo as coordenadas de Curitiba
latitude= -25.4290
longitude= -49.2671

# %%
# Criando um mapa centrado em Curitiba
mapa = folium.Map(localition=[latitude, longitude], zoom_start=12)

# %%
# Adicionando um marcador para Curitiba
folium.Marker([latitude, longitude], popup='Curitiba, RS, Brasil').add_to(mapa)

# %%
# Exibindo o mapa
mapa
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
# ...

# %%
# Definindo as coordenadas de Belo Horizonte
latitude= -19.9173
longitude= -43.9345

# %%
# Criando um mapa centrado em Belo Horizonte
mapa = folium.Map(localition=[latitude, longitude], zoom_start=12)

# %%
# Adicionando um marcador para Curitiba
folium.Marker([latitude, longitude], popup='Curitiba, RS, Brasil').add_to(mapa)

# %%
# Exibindo o mapa
mapa
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
# ...
